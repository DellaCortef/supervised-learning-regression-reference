# %% [markdown]
# # Machine Learning GridSearch Hyperparameters - Regression

# %% [markdown]
# ## Importing Libs

# %%
# Standard libs
import time
import numpy as np
import pandas as pd

# Model Selection libs
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# Machine Learning libs
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import SGDRegressor

# %%
df_abt_reg = pd.read_csv('/Users/dellacorte/py-projects/data-science/supervised-learning-regression-reference/databases/house-price.csv', sep=';')
df_abt_reg.head()
# Out:
#   zoneamento  tam_terreno forma_terreno  qualidade_geral  condicao  \
# 0         RL    785.03035           Reg                7         5
# 1         RL    891.86880           Reg                6         8
# 2         RL   1045.15875           IR1                7         5
# 3         RL    887.22365           IR1                7         5
# 4         RL   1324.79678           IR1                8         5
#
#    ano_construcao qualidade_aquecedor ar_condicionado  tam_primeiro_andar  \
# 0            2003                  Ex               Y           79.524968
# 1            1976                  Ex               Y          117.243586
# 2            2001                  Ex               Y           85.470760
# 3            1915                  Gd               Y           89.279783
# 4            2000                  Ex               Y          106.373935
#
#    tam_segundo_andar  ...  qtde_banheiros  qtde_comodos qtde_lareiras  \
# 0          79.339162  ...              30             8             0
# 1           0.000000  ...               2             6             1
# 2          80.453998  ...               2             6             1
# 3          70.234668  ...               1             7             1
# 4          97.826859  ...               2             9             1
#
#    qtde_carros_garagem  tam_garagem  tam_piscina  qualidade_piscina  \
# 0                    2    50.910844          0.0              NotAv
# 1                    2    42.735380          0.0              NotAv
# 2                    2    56.485024          0.0              NotAv
# 3                    3    59.643726          0.0              NotAv
# 4                    3    77.666908          0.0              NotAv
#
#    mes_venda  ano_venda         preco
# 0          2       2008  8.465100e+05
# 1          5       2007  7.344784e+05
# 2          9       2008  9.074100e+05
# 3          2       2006  5.684000e+05
# 4         12       2008  1.015000e+06
#
# [5 rows x 23 columns]

# %%
# !pip install feature-engine -U
# Out:
# Requirement already satisfied: feature-engine in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (1.3.0)
# Collecting feature-engine
#   Downloading feature_engine-1.8.3-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.2 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (1.23.0)
# Requirement already satisfied: pandas>=2.2.0 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (2.2.3)
# Collecting scikit-learn>=1.4.0 (from feature-engine)
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: scipy>=1.4.1 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from feature-engine) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.2.0->feature-engine) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.2.0->feature-engine) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.4.0->feature-engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.4.0->feature-engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.11.1->feature-engine) (24.2)
# Requirement already satisfied: six in /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature-engine) (1.17.0)
# Downloading feature_engine-1.8.3-py2.py3-none-any.whl (378 kB)
# Using cached scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
# Installing collected packages: scikit-learn, feature-engine
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: feature-engine
#     Found existing installation: feature-engine 1.3.0
#     Uninstalling feature-engine-1.3.0:
#       Successfully uninstalled feature-engine-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pdpbox 0.3.0 requires xgboost>=1.7.1, but you have xgboost 1.6.2 which is incompatible.
# cesium 0.12.3 requires numpy<3.0,>=2.0, but you have numpy 1.23.0 which is incompatible.
# dtreeviz 2.2.1 requires graphviz>=0.9, but you have graphviz 0.8.4 which is incompatible.
# scprep 1.2.3 requires pandas<2.1,>=0.25, but you have pandas 2.2.3 which is incompatible.
# Successfully installed feature-engine-1.8.3 scikit-learn-1.6.1

# %%
cat_vars = []
num_vars = ['tam_terreno', 'qualidade_geral', 'ano_construcao', 'tam_primeiro_andar', 'tam_segundo_andar', 'tam_sala_estar',
            'qtde_banheiros',	'qtde_comodos',	'qtde_lareiras',	'qtde_carros_garagem',	'tam_garagem', 'ano_venda']
modeling_vars = cat_vars + num_vars

X = df_abt_reg[modeling_vars].copy()
y = df_abt_reg['preco'].copy()

# %% [markdown]
# ### LinearRegression
#
# The main hyperparameters that we can use in GridSearch:
#
# * `fit_intercept`: Whether or not to compute the intercept. If set to `False`, the intercept will not be computed.

# %%
t1 = time.time()

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps=[('linear_regression', LinearRegression())])

parametros = {
  'linear_regression__fit_intercept': [True, False],
}

grid_search = GridSearchCV(pipeline, parametros, scoring='neg_median_absolute_error', cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X, y)

print()
print('='*100)
print(grid_search.best_params_)
print('\nIt took {} seconds for GridSearch for LinearRegression'.format(time.time() - t1))
print('='*100)
print()
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ====================================================================================================
# {'linear_regression__fit_intercept': False}
#
# It took 2.0857908725738525 seconds for GridSearch for LinearRegression
# ====================================================================================================

# %% [markdown]
# ### SGDRegressor
#
# The main hyperparameters that we can use in GridSearch:
#
# * `fit_intercept`: Whether or not to compute the intercept. If set to `False`, the intercept will not be computed.
#
# * `learning_rate`: Learning rate, values ​​to test: `['constant', 'optimal', 'adaptive']`.
#
# * `penalty`: Regularization to be used: `['l2', 'l1', None]`
#
# * `early_stopping`: Whether to use early stopping to end training when the validation score is not improving: `[True, False]`
#
# * `n_iter_no_change`: Number of iterations without improvements before ending training: `[5, 30, 50]`

# %%
t2 = time.time()

pipeline = Pipeline(steps=[('sdg_reg', SGDRegressor())])

parametros = {
  'sdg_reg__fit_intercept': [True, False],
  'sdg_reg__learning_rate': ['constant', 'optimal', 'adaptive'],
  'sdg_reg__penalty': ['l2', 'l1', None],
  'sdg_reg__early_stopping': [True, False],
  'sdg_reg__n_iter_no_change': [5, 30, 50]
}

grid_search = GridSearchCV(pipeline, parametros, scoring='neg_median_absolute_error', cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X, y)

print()
print('='*100)
print(grid_search.best_params_)
print('\nIt took {} seconds for GridSearch for SGDRegressor'.format(time.time() - t2))
print('='*100)
print()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ====================================================================================================
# {'sdg_reg__early_stopping': False, 'sdg_reg__fit_intercept': True, 'sdg_reg__learning_rate': 'adaptive', 'sdg_reg__n_iter_no_change': 30, 'sdg_reg__penalty': 'l2'}
#
# It took 5.811716079711914 seconds for GridSearch for SGDRegressor
# ====================================================================================================
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %% [markdown]
# ### Ridge
#
# The main hyperparameters that we can use in GridSearch:
#
# * `alpha`: Regularization strength. Must be a positive decimal value. Regularization improves the conditioning of the problem and reduces the variance of the estimates. Larger values ​​specify stronger regularization.
#
# * `fit_intercept`: Whether or not to compute the intercept. If set to `False`, the intercept will not be computed.

# %%
t3 = time.time()

pipeline = Pipeline(steps=[('ridge_regression', Ridge())])

parametros = {
  'ridge_regression__alpha': [0.01, 0.1, 1.0, 10, 100],
  'ridge_regression__fit_intercept': [True, False],
}

grid_search = GridSearchCV(pipeline, parametros, scoring='neg_median_absolute_error', cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X, y)

print()
print('='*100)
print(grid_search.best_params_)
print('\nIt took {} seconds for GridSearch for Ridge'.format(time.time() - t3))
print('='*100)
print()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
# ====================================================================================================
# {'ridge_regression__alpha': 100, 'ridge_regression__fit_intercept': False}
#
# It took 0.18117880821228027 seconds for GridSearch for Ridge
# ====================================================================================================

# %% [markdown]
# ### Lasso
#
# The main hyperparameters that we can use in GridSearch:
#
# * `alpha`: Constne that multiplies the L1 term. The default is `1.0`. If `alpha=0` is the equivalent of Linear Regression.
#
# * `fit_intercept`: Whether or not to compute the intercept. If set to `False`, the intercept will not be computed.

# %%
t4 = time.time()

pipeline = Pipeline(steps=[('lasso', Lasso())])

parametros = {
  'lasso__alpha': [0.01, 0.1, 1.0, 10, 100],
  'lasso__fit_intercept': [True, False],
}

grid_search = GridSearchCV(pipeline, parametros, scoring='neg_median_absolute_error', cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X, y)

print()
print('='*100)
print(grid_search.best_params_)
print('\nIt took {} seconds for GridSearch for Lasso'.format(time.time() - t4))
print('='*100)
print()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.468e+13, tolerance: 1.251e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.371e+13, tolerance: 1.193e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.431e+13, tolerance: 1.272e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.311e+13, tolerance: 1.150e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.178e+13, tolerance: 1.192e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e+13, tolerance: 7.433e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.513e+13, tolerance: 7.527e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+13, tolerance: 7.703e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+13, tolerance: 7.462e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.265e+13, tolerance: 1.193e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.463e+13, tolerance: 1.251e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.263e+13, tolerance: 1.150e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+13, tolerance: 7.373e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.401e+13, tolerance: 1.272e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.513e+13, tolerance: 7.527e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.054e+13, tolerance: 1.192e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e+13, tolerance: 7.433e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.376e+12, tolerance: 1.150e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+13, tolerance: 7.703e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e+11, tolerance: 1.192e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+13, tolerance: 7.703e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.415e+13, tolerance: 1.251e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e+13, tolerance: 7.433e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+13, tolerance: 7.462e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+13, tolerance: 7.373e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.093e+13, tolerance: 1.272e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+13, tolerance: 7.373e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+13, tolerance: 7.462e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.170e+12, tolerance: 1.193e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.418e+10, tolerance: 1.150e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.513e+13, tolerance: 7.527e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.042e+13, tolerance: 1.251e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e+13, tolerance: 7.433e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.792e+10, tolerance: 1.272e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+13, tolerance: 7.703e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.729e+12, tolerance: 1.251e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+13, tolerance: 7.373e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.514e+13, tolerance: 7.527e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.429e+13, tolerance: 7.433e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+13, tolerance: 7.462e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.515e+13, tolerance: 7.527e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.360e+13, tolerance: 7.373e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.249e+13, tolerance: 7.462e+10
#   model = cd_fast.enet_coordinate_descent(
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.477e+13, tolerance: 7.703e+10
#   model = cd_fast.enet_coordinate_descent(
# ====================================================================================================
# {'lasso__alpha': 100, 'lasso__fit_intercept': False}
#
# It took 0.2935349941253662 seconds for GridSearch for Lasso
# ====================================================================================================
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.767e+13, tolerance: 9.375e+10
#   model = cd_fast.enet_coordinate_descent(
